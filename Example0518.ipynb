# %% [markdown]
# <a href="https://colab.research.google.com/github/JunShwai/Google_Colab/blob/main/Example0518.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
if __name__ == '__main__':
    n = int(input())
    
    for i in range(0,n):
        print(i**2)
# Out:
# 5
# 0
# 1
# 4
# 9
# 16

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import calendar

'''
def is_leap(year):
    if (year % 4 == 0) and (year % 100 != 0 or year % 400 == 0):
            leap = True
        else:
            leap = False

        return leap
'''
def is_leap(year):
    return calendar.isleap(year)

year = int(input())
print(is_leap(year))
# Out:
# 1990
# False
