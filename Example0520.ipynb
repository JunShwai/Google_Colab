# %% [markdown]
# <a href="https://colab.research.google.com/github/JunShwai/Google_Colab/blob/main/Example0520.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
if __name__ == '__main__':
    n = int(input())
    #arr = map(int, input().split(','))
    arr = map(int, input().split())
    print (sorted(set(arr),reverse = True)[1])
# Out:
# 5
# 2 3 6 6 5
# 5
