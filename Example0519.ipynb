# %% [markdown]
# <a href="https://colab.research.google.com/github/JunShwai/Google_Colab/blob/main/Example0519.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
if __name__ == '__main__':
    n = int(input())
    
    for n in range(1,n+1):
        print(n, end = '')
# Out:
# 5
# 12345
