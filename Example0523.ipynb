# %% [markdown]
# <a href="https://colab.research.google.com/github/JunShwai/Google_Colab/blob/main/Example0523.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from decimal import Decimal


if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()


query_scores = student_marks[query_name]

# sum() : 計算總和值
total_scores = sum(query_scores)

# Decimal() : 將浮點數轉換為高精度的十進制並除以三以計算平均分數
avg = Decimal(total_scores/3)

# round() : 用途是進行四捨五入並以兩位小數點的格式輸出。
print(round(avg,2))
